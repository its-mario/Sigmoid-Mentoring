# %% [markdown]
# # Exam Model Training

# %%
import pandas as pd

df = pd.read_csv("data/students_depression_prepared.csv")
df.head()
# Out:
#    Gender   Age  City  Academic Pressure  CGPA  Study Satisfaction  \
# 0     1.0  33.0   3.2                5.0  8.97                 2.0
# 1     0.0  24.0   3.8                2.0  5.90                 5.0
# 2     1.0  31.0   2.1                3.0  7.03                 5.0
# 3     0.0  28.0   1.0                3.0  5.59                 2.0
# 4     0.0  25.0   1.0                4.0  8.13                 3.0
#
#    Sleep Duration  Dietary Habits  Degree  \
# 0             5.0             0.0     1.0
# 1             5.0             1.0     1.0
# 2             1.0             0.0     1.0
# 3             8.0             1.0     1.0
# 4             5.0             1.0     2.0
#
#    Have you ever had suicidal thoughts ?  Work/Study Hours  Financial Stress  \
# 0                                    1.0               3.0               0.0
# 1                                    0.0               3.0               1.0
# ...

# %% [markdown]
# As the task asks, I should train a model that can determine whether a student is experiencing a depressive phase therefor along the training I should focus on having the highest recall score.

# %%
abs(df.corr()["Depression"]).sort_values()[::-1]
# Out:
# Depression                               1.000000
# Have you ever had suicidal thoughts ?    0.546387
# Academic Pressure                        0.474810
# Financial Stress                         0.364303
# Age                                      0.227023
# Work/Study Hours                         0.208141
# Dietary Habits                           0.207346
# Study Satisfaction                       0.168748
# Degree                                   0.113825
# Sleep Duration                           0.084907
# Family History of Mental Illness         0.053331
# City                                     0.038570
# CGPA                                     0.020739
# Gender                                   0.001446
# Name: Depression, dtype: float64

# %% [markdown]
# Now my plan is to select some features to train on them several models select the best model and working with them to explain the influence of features on it.

# %%
correlation_columns = ['pearson', 'kendall', 'spearman']
correlation_dataframe = pd.DataFrame({}, columns=correlation_columns)

for corr_method in correlation_columns:
    correlation_dataframe[corr_method] = abs(df.corr(method=corr_method)["Depression"]).sort_values()[::-1]

correlation_dataframe
# Out:
#                                         pearson   kendall  spearman
# Depression                             1.000000  1.000000  1.000000
# Have you ever had suicidal thoughts ?  0.546387  0.546387  0.546387
# Academic Pressure                      0.474810  0.423560  0.472311
# Financial Stress                       0.364303  0.325410  0.363550
# Age                                    0.227023  0.190020  0.225916
# Work/Study Hours                       0.208141  0.170509  0.200261
# Dietary Habits                         0.207346  0.196324  0.208006
# Study Satisfaction                     0.168748  0.151206  0.168915
# Degree                                 0.113825  0.107184  0.113748
# Sleep Duration                         0.084907  0.079256  0.086721
# Family History of Mental Illness       0.053331  0.053331  0.053331
# City                                   0.038570  0.031373  0.037084
# CGPA                                   0.020739  0.016746  0.020448
# ...

# %% [markdown]
# Here we could assume two things:
# 1. the ranks we gave to the cities weren't too relevant
# 2. the cities don't influence the mental wellbeing of the students

# %%
from kydavra import PearsonCorrelationSelector

pearson = PearsonCorrelationSelector(min_corr=0.2)
selected_columns = pearson.select(df, 'Depression')

# %% [markdown]
# Here I applied feature selection. (don't have a clear explanation why I did this, in the SHB is written that it somehow helps the to better describe  model, although I didn't quit understand those VEN graphs)

# %%
selected_columns.append("Depression")
selected_columns
# Out:
# ['Age',
#  'Academic Pressure',
#  'Dietary Habits',
#  'Have you ever had suicidal thoughts ?',
#  'Work/Study Hours',
#  'Financial Stress',
#  'Depression']

# %%
df_training = df[selected_columns]

# %% [markdown]
# Now let's check if the dataset need class balancing.

# %%
from matplotlib import pyplot as plt

print(f"{len(df_training[df_training["Depression"]==1])}/{len(df_training[df_training["Depression"]==0])}")
fig, ax = plt.subplots()

y = [len(df_training[df_training["Depression"]==1]), len(df_training[df_training["Depression"]==0])]
ax.bar(["Depressed","Not Depressed"], y, width=1,  linewidth=0.7)
# Out:
# 16300/11515
# <BarContainer object of 2 artists>

# %% [markdown]
# As we could see, there is a significant difference in the class numbers, therefore we need to apply the class balancing methods.

# %% [markdown]
# Before proceeding to Class Balancing we need to split data into training and testing.

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(df_training, test_size=0.3, random_state=40)
train = train.reset_index(drop=True)
test = test.reset_index(drop=True)

# %%
train.shape
# Out:
# (19470, 7)

# %%
from crucio import SMOTEENN

smoteenn = SMOTEENN()
balanced_df = smoteenn.balance(train, "Depression")
balanced_df.shape
# Out:
# (20334, 7)

# %% [markdown]
# Now that we have everything ready for training let's train it.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score

models = [
    LogisticRegression(),
    RandomForestClassifier(),
    SVC(),
    GaussianNB(),
    DecisionTreeClassifier(),
]

X = balanced_df.drop("Depression", axis=1)
y = balanced_df["Depression"]

x_test = test.drop("Depression", axis=1)
y_test = test["Depression"]

results = pd.DataFrame({})
for model in models:
    model.fit(X, y)

    y_pred = model.predict(x_test)
    score = accuracy_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)

    results = pd.concat([
        results,
        pd.DataFrame({
            "Accuracy": score,
            "Recall": recall,
        },
            index=[model.__class__.__name__]
        )
    ],)

# %%
results
# Out:
#                         Accuracy    Recall
# LogisticRegression      0.836189  0.833850
# RandomForestClassifier  0.824086  0.851622
# SVC                     0.837867  0.840050
# GaussianNB              0.828520  0.818351
# DecisionTreeClassifier  0.796165  0.807605

# %% [markdown]
# As we could see, the biggest recall score is for RandomForestClassifier. Now I would like to improve these performances.

# %%
from sklearn.model_selection import GridSearchCV

tuned_parameters = {
    'n_estimators': range(50, 200, 50),
    'max_depth': range(1, 20, 1),
    'max_features': ["auto", "sqrt", "log2"],
    'criterion': ['gini', "entropy", "log_loss"]
}

X_all = df_training.drop("Depression", axis=1)
y_all = df_training["Depression"]

clf = GridSearchCV(RandomForestClassifier(), tuned_parameters, scoring='recall', n_jobs=12)
clf.fit(X_all, y_all)

print(clf.best_params_)
print(clf.best_score_)
# Out:
# {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'n_estimators': 150}
# 0.9494478527607363

# %%
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

best_params = {'criterion': 'log_loss', 'max_depth': 13, 'max_features': 'sqrt', 'n_estimators': 150}
model = RandomForestClassifier(**best_params)

model.fit(X, y)
y_pred = model.predict(x_test)
print(accuracy_score(y_test, y_pred))
print(recall_score(y_test, y_pred))

ConfusionMatrixDisplay.from_predictions(y_test, y_pred)
# Out:
# 0.8355901737567406
# 0.861128332300062

# %% [markdown]
# Here, the FN corner makes me a bit worried, but for now I don't know what caused this. Btw because the classifier is RandomForest we don't need to apply any scaling for data.

# %%
import shap
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
explainer = shap.Explainer(model.predict, X, feature_names = list(train.columns)[:-1])

shap_values = explainer(x_test)
shap.plots.bar(shap_values, max_display=14)
# Out:
# ExactExplainer explainer: 8346it [08:26, 16.15it/s]

# %% [markdown]
# This graph shows the importance of each feature on the predicted value.

# %% [markdown]
# Now I would like to see waterfall for one of those FN values we got.

# %%
mask = (y_pred == 0) & (y_test == 1)
indices = mask[mask].index.tolist()

# %%
shap.plots.waterfall(shap_values[indices[5]], max_display=14)

# %% [markdown]
# Here we could observe that feature **Have you ever had suicidal thoughts ?**  have a disproportional effect on the decision.  I don't know for sure what will be best to do in this situation but we could try to train on all the features maybe we will be able to have more features that describe properly the **Depression**.

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(df, test_size=0.3, random_state=40)
train = train.reset_index(drop=True)
test = test.reset_index(drop=True)

# %%
# from crucio import SMOTEENN
# 
# smoteenn = SMOTEENN()
# balanced_df = smoteenn.balance(train, "Depression")
# balanced_df.shape
# Out:
# (19488, 14)

# %% [markdown]
# Post-scriptum: Actually by skipping the phase of balancing the dataset teh model will tend to predict more Depression, as our goal is to make sure that people don't suffer this method will help ensure that. Actually I will even say that will be reasonable to oversampling with Depression cases.

# %%
balanced_df = train

# %%
# from crucio import ICOTE
# 
# icote = ICOTE()
# balanced_df = icote.balance(train, "Depression")
# balanced_df.shape

# %% [markdown]
# Here I tried to use another type of oversampling, but it crashed because of lack of memory.

# %%
X = balanced_df.drop("Depression", axis=1)
y = balanced_df["Depression"]

x_test = test.drop("Depression", axis=1)
y_test = test["Depression"]

# %%
from sklearn.model_selection import GridSearchCV

tuned_parameters = {
    'n_estimators': range(50, 200, 50),
    'max_depth': range(1, 20, 1),
    'max_features': ["auto", "sqrt", "log2"],
    'criterion': ['gini', "entropy", "log_loss"]
}

X_all = df_training.drop("Depression", axis=1)
y_all = df_training["Depression"]

clf = GridSearchCV(RandomForestClassifier(), tuned_parameters, scoring='recall', n_jobs=12)
clf.fit(X, y)

print(clf.best_params_)
print(clf.best_score_)
# Out:
# {'criterion': 'entropy', 'max_depth': 1, 'max_features': 'sqrt', 'n_estimators': 150}
# 0.9741736554610018

# %%
from sklearn.metrics import ConfusionMatrixDisplay

best_params = {'criterion': 'log_loss', 'max_depth': 14, 'max_features': 'log2', 'n_estimators': 100}

model = RandomForestClassifier(**best_params)

model.fit(X, y)
y_pred = model.predict(x_test)
print(accuracy_score(y_test, y_pred))
print(recall_score(y_test, y_pred))

ConfusionMatrixDisplay.from_predictions(y_test, y_pred)
# Out:
# 0.8415817855002996
# 0.889026658400496

# %% [markdown]
# As we see the result isn't that different from the one above. For now this is all I know about improving the results.

# %% [markdown]
# ### Conclusion
# In this two jupyter notebooks I cleaned and prepared data for training, and then trained and applied some techniques for performance improvement. The final trained model gives us a recall score of 0.889 which I would say it's good but could be better.

# %%
x = [5507.091456,
    8415.330765,
    14979.28876,
    18267.42532,
    22695.89206,
]

y1 = [
    0.043624358,
0.040033584,
0.02779759,
0.024355069,
0.022749548
]

y2 = [
    0.036708736,
    0.033016589,
    0.028584276,
    0.027200737,
    0.025763994,
]

# %%
import matplotlib.pyplot as plt

plt.plot(x, y1, x, y2)

# %%
x = [
    150,
175,
200,
225,
250,
300,
325,

]

y = [
    127.53,
176.58,
235.44,
284.49,
362.97,
500.31,
598.41,

]

# %%
plt.plot(x,y)

# %%
x= [
    2316,
2250,
2092,
1896,
1736,
1562,
1301,
]

y = [
    0,
22.25,
41.34,
56.01,
60.03,
61.77,
64.32
]

# %%
plt.plot(x,y)
